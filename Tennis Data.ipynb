# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('tennis_2015.csv')

# %%
df.head(10)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2015-329        Tokyo    Hard         32             A      20151005
# 1   2015-329        Tokyo    Hard         32             A      20151005
# 2   2015-329        Tokyo    Hard         32             A      20151005
# 3   2015-329        Tokyo    Hard         32             A      20151005
# 4   2015-329        Tokyo    Hard         32             A      20151005
# 5   2015-329        Tokyo    Hard         32             A      20151005
# 6   2015-329        Tokyo    Hard         32             A      20151005
# 7   2015-329        Tokyo    Hard         32             A      20151005
# 8   2015-329        Tokyo    Hard         32             A      20151005
# 9   2015-329        Tokyo    Hard         32             A      20151005
#
#    match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 0          1     104527          1.0          NaN    ...          1.0   2.0
# ...

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")

# %%
missing_values_table(df)
# Out:
# Your selected dataframe has 49 columns.
# There are 32 columns that have missing values.

# %%
array = ['0']
df.loc[df['w_svpt'].isin(array)]
# Out:
#      tourney_id   tourney_name surface  draw_size tourney_level  tourney_date  \
# 387    2015-540      Wimbledon   Grass        128             G      20150629
# 1173  2015-6967       Shenzhen    Hard         28             A      20150928
# 1710  2015-6242  Winston-Salem    Hard         48             A      20150823
# 1869   2015-414        Hamburg    Clay         32             A      20150727
# 2199   2015-341           Metz    Hard         28             A      20150921
#
#       match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced  \
# 387          72     105053          NaN          NaN    ...          0.0
# 1173         23     104198          4.0          NaN    ...          0.0
# 1710         42     105449         13.0          NaN    ...          0.0
# 1869         26     104312          4.0          NaN    ...          0.0
# 2199         21     104259          5.0           WC    ...          0.0
#
# ...

# %%
for cell in df['w_svpt']:
	if cell  == 0:
		print("zero in cell")
# Out:
# zero in cell
# zero in cell
# zero in cell
# zero in cell
# zero in cell

# %%
df = df[np.isfinite(df['w_svpt'])]

# %%
clean_df=df[(df != 0).all(1)]

# %%
clean_two_df = clean_df.replace({'surface':{'Hard': 1, 'Clay': 2, 'Grass': 3}})
clean_two_df.head()
# Out:
#   tourney_id tourney_name  surface  draw_size tourney_level  tourney_date  \
# 1   2015-329        Tokyo        1         32             A      20151005
# 2   2015-329        Tokyo        1         32             A      20151005
# 3   2015-329        Tokyo        1         32             A      20151005
# 7   2015-329        Tokyo        1         32             A      20151005
# 8   2015-329        Tokyo        1         32             A      20151005
#
#    match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 1          2     105147          NaN           WC    ...         14.0   1.0
# 2          3     105572          NaN            Q    ...          7.0  15.0
# 3          4     105311          NaN          NaN    ...          6.0   9.0
# 7          8     104180          NaN          NaN    ...          4.0   4.0
# 8          9     105332          NaN          NaN    ...         13.0   3.0
#
# ...

# %%
df['winner_name'].unique()
# Out:
# array(['Stanislas Wawrinka', 'Tatsuma Ito', 'Austin Krajicek',
#        'Joao Sousa', 'Gilles Simon', 'Jiri Vesely', 'Jeremy Chardy',
#        'Gilles Muller', 'Benoit Paire', 'Marcos Baghdatis', 'Nick Kyrgios',
#        'Roberto Bautista Agut', 'Marin Cilic', 'Steve Johnson',
#        'Sam Querrey', 'Kei Nishikori', 'Alexander Zverev',
#        'Nicolas Almagro', 'Grigor Dimitrov', 'John Millman', 'Jack Sock',
#        'Fernando Verdasco', 'Leonardo Mayer', 'Federico Delbonis',
#        'Steve Darcis', 'Tomas Berdych', 'Richard Gasquet',
#        'Bastian Trinker', 'Paolo Lorenzi', 'Philipp Kohlschreiber',
#        'Dusan Lajovic', 'Andreas Haider Maurer', 'Martin Klizan',
#        'Fabio Fognini', 'Damir Dzumhur', 'Borna Coric', 'Aljaz Bedene',
#        'Blaz Kavcic', 'Gael Monfils', 'Dominic Thiem', 'David Goffin',
#        'Ivo Karlovic', 'Bernard Tomic', 'Jared Donaldson',
#        'Jerzy Janowicz', 'Tommy Robredo', 'Thomaz Bellucci',
# ...

# %%
df.shape
# Out:
# (2958, 49)

# %%
df['winner_name'].value_counts()
# Out:
# Novak Djokovic                83
# Andy Murray                   71
# Roger Federer                 63
# Rafael Nadal                  61
# Tomas Berdych                 57
# Kei Nishikori                 55
# David Ferrer                  55
# Stanislas Wawrinka            55
# Kevin Anderson                46
# John Isner                    45
# Richard Gasquet               43
# Gilles Simon                  43
# Roberto Bautista Agut         42
# Bernard Tomic                 40
# David Goffin                  39
# Joao Sousa                    38
# Ivo Karlovic                  38
# Steve Johnson                 37
# Dominic Thiem                 36
# Marin Cilic                   35
# Viktor Troicki                35
# Jack Sock                     35
# Gael Monfils                  34
# Gilles Muller                 33
# Philipp Kohlschreiber         33
# Milos Raonic                  33
# Grigor Dimitrov               33
# Jo Wilfried Tsonga            32
# ...

# %%
df['loser_name'].value_counts()
# Out:
# Joao Sousa                    31
# Adrian Mannarino              30
# Thomaz Bellucci               30
# Lukas Rosol                   30
# Jiri Vesely                   30
# Roberto Bautista Agut         29
# Santiago Giraldo              28
# Borna Coric                   28
# Steve Johnson                 28
# Bernard Tomic                 28
# Dominic Thiem                 28
# Viktor Troicki                28
# Martin Klizan                 27
# Simone Bolelli                27
# Jeremy Chardy                 27
# Sergiy Stakhovsky             27
# Andreas Haider Maurer         26
# Alexandr Dolgopolov           26
# Fabio Fognini                 26
# Fernando Verdasco             26
# Feliciano Lopez               26
# Pablo Cuevas                  26
# David Goffin                  25
# Andreas Seppi                 25
# John Isner                    25
# Guillermo Garcia Lopez        25
# Pablo Carreno Busta           25
# Ivo Karlovic                  25
# ...

# %%
w_fst_srv_pct_lst=[]
w_fst_srv_pct_diff_lst=[]
win_lose=[]
w_name=[]
w_age=[]
w_age_diff_lst=[]
w_height_diff=[]
w_rank=[]
w_rank_diff_lst=[]
w_scd_srv_pct_lst=[]
w_bp_saved_pct_lst=[]
w_surface=[]
for i, row in clean_two_df.iterrows():
    w_fst_srv_pct = row['w_1stWon']/row['w_svpt']#winner first serve percentage
    w_fst_srv_pct_lst.append(w_fst_srv_pct)
    l_fst_srv_pct = row['l_1stWon']/row['l_svpt']
    w_l_fst_sv_pct_diff = w_fst_srv_pct - l_fst_srv_pct#loser first serve percentage 
    w_name.append(row['winner_name'])
    w_age.append(row['winner_age'])
    w_scd_srv_pct= row['w_2ndWon']/row['w_svpt']#second serve % 
    w_scd_srv_pct_lst.append(w_scd_srv_pct)
    w_rank.append(row['winner_rank'])
    w_bp_saved_pct = row['w_bpSaved']/row['w_bpFaced']#break point saved %
    w_bp_saved_pct_lst.append(w_bp_saved_pct)
    w_rank_diff= row['winner_rank']-row['loser_rank']#rank diff
    w_rank_diff_lst.append(w_l_rank_diff)
    w_age_diff= row['winner_age']-row['loser_age']#age diff
    w_age_diff_lst.append(w_age_diff)
    win_lose.append(1)
    w_surface.append((row['surface']))
print(len(w_fst_srv_pct_lst), len(win_lose), len(w_name), len(w_age), len(w_rank), len(w_scd_srv_pct_lst), len(w_bp_saved_pct_lst), len(w_age_diff_lst),len(w_l_rank_diff_lst),len(w_surface))
# Out:
# 1559 1559 1559 1559 1559 1559 1559 1559 1559 1559

# %%
len(w_fst_srv_pct_lst)
# Out:
# 1559

# %%
len(clean_df)
# Out:
# 1559

# %%
#match ups
df_Nadal_win = clean_two_df.loc[clean_two_df['winner_name'] == 'Rafael Nadal', 'loser_name']
df_Nadal_win
# Out:
# 121                   Jeremy Chardy
# 172                    Ivo Karlovic
# 184                    Milos Raonic
# 190              Stanislas Wawrinka
# 218                     Lukas Rosol
# 230                  Kevin Anderson
# 355                 Thomaz Bellucci
# 514                 Mikhail Youzhny
# 692                   Igor Sijsling
# 712                    Donald Young
# 1095    Diego Sebastian Schwartzman
# 1477                Mikhail Youzhny
# 1517                    Tim Smyczek
# 1547                 Kevin Anderson
# 1608                 Carlos Berlocq
# 1924                Grigor Dimitrov
# 1965                   Marsel Ilhan
# 2326               Marcos Baghdatis
# 2424                  Fabio Fognini
# 2468                    Lukas Rosol
# 2478                Grigor Dimitrov
# 2483                    Marin Cilic
# 2486                Richard Gasquet
# 2559                Nicolas Almagro
# 2587               Andrey Kuznetsov
# 2601                      Jack Sock
# ...

# %%
df_Nadal_lose = clean_two_df.loc[clean_two_df['loser_name'] == 'Rafael Nadal', 'winner_name']
df_Nadal_lose
# Out:
# 131         Feliciano Lopez
# 193      Jo Wilfried Tsonga
# 236      Stanislas Wawrinka
# 399            Dustin Brown
# 727            Milos Raonic
# 811       Fernando Verdasco
# 1123          Fabio Fognini
# 1248    Alexandr Dolgopolov
# 1929            Andy Murray
# 2109         Michael Berrer
# Name: winner_name, dtype: object

# %%
tourney_date=[]
l_player_id=[]
w_player_id=[]
w_player_name=[]
l_player_name=[]
w_rank=[]
l_rank=[]
w_age=[]
l_age=[]
w_fst_srv_pct_lst=[]
l_fst_srv_pct_lst=[]
w_scd_srv_pct_lst=[]
l_scd_srv_pct_lst=[]
w_bp_saved_pct_lst=[]
l_bp_saved_pct_lst=[]

for i, row in clean_two_df.iterrows():
    w_fst_srv_pct = row['w_1stWon']/row['w_svpt']#winner first serve percentage
    w_fst_srv_pct_lst.append(w_fst_srv_pct)
    l_fst_srv_pct = row['l_1stWon']/row['l_svpt']
    l_fst_srv_pct_lst.append(l_fst_srv_pct)
    w_player_id.append(row['winner_id'])
    l_player_id.append(row['loser_id'])
    w_age.append(row['winner_age'])
    l_age.append(row['loser_age'])
    w_player_name.append(row['winner_name'])
    l_player_name.append(row['loser_name'])
    w_scd_srv_pct= row['w_2ndWon']/row['w_svpt']#second serve % 
    w_scd_srv_pct_lst.append(w_scd_srv_pct)
    l_scd_srv_pct= row['l_2ndWon']/row['l_svpt']
    l_scd_srv_pct_lst.append(l_scd_srv_pct)
    w_rank.append(row['winner_rank'])
    l_rank.append(row['loser_rank'])
    w_bp_saved_pct = row['w_bpSaved']/row['w_bpFaced']#break point saved %
    w_bp_saved_pct_lst.append(w_bp_saved_pct)
    l_bp_saved_pct = row['l_bpSaved']/row['l_bpFaced']
    l_bp_saved_pct_lst.append(l_bp_saved_pct)
    tourney_date.append(row['tourney_date'])
print(len(w_fst_srv_pct_lst),len(l_fst_srv_pct_lst), len(w_player_id), len(l_player_id), len(w_age), len(l_age), len(l_rank), len(w_rank), len(w_scd_srv_pct_lst), len(l_scd_srv_pct_lst),len(w_bp_saved_pct_lst), len(w_player_name), len(l_player_name),len(l_bp_saved_pct_lst),len(tourney_date))
rows= zip(tourney_date,
l_player_id,
w_player_id,
w_player_name,
l_player_name,
w_rank,
l_rank,
w_age,
l_age,
w_fst_srv_pct_lst,
l_fst_srv_pct_lst,
w_scd_srv_pct_lst,
l_scd_srv_pct_lst,
w_bp_saved_pct_lst,
l_bp_saved_pct_lst
)
headers=['tourney_date',
'loser_player_id',
'winner_player_id',
'w_player_name',
'l_player_name',
'winner_rank',
'loser_rank',
'winner_age',
'loser_age',
'w_fst_srv_pct',
'l_fst_srv_pct',
'w_scd_srv_pct',
'l_scd_srv_pct',
'w_bp_saved_pct',
'l_bp_saved_pct']
# Out:
# 1559 1559 1559 1559 1559 1559 1559 1559 1559 1559 1559 1559 1559 1559 1559

# %%
csvfile = "/Users/forrestbadgley/Documents/DataScience/Homework/FinalProject/pre_processed/tennis_2015_processed.csv"

with open(csvfile, "w") as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    for row in rows:
        writer.writerow(row)

# %%
df = pd.read_csv('pre_processed/tennis_2015_processed.csv')
df.head(10)
# Out:
#    tourney_date  loser_player_id  winner_player_id          w_player_name  \
# 0      20151005           106415            105147            Tatsuma Ito
# 1      20151005           105051            105572        Austin Krajicek
# 2      20151005           103852            105311             Joao Sousa
# 3      20151005           104731            104180          Gilles Muller
# 4      20151005           105777            105332           Benoit Paire
# 5      20151005           105077            106401           Nick Kyrgios
# 6      20151005           104755            105138  Roberto Bautista Agut
# 7      20151005           105385            105227            Marin Cilic
# 8      20151005           106071            105449          Steve Johnson
# 9      20151005           106432            105453          Kei Nishikori
#
#         l_player_name  winner_rank  loser_rank  winner_age  loser_age  \
# 0  Yoshihito Nishioka        127.0       148.0   27.381246  20.021903
# ...

# %%
df_2014 = pd.read_csv('tennis_2014.csv')
df_2014.head(10)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2014-301     Auckland    Hard         28             A      20140106
# 1   2014-301     Auckland    Hard         28             A      20140106
# 2   2014-301     Auckland    Hard         28             A      20140106
# 3   2014-301     Auckland    Hard         28             A      20140106
# 4   2014-301     Auckland    Hard         28             A      20140106
# 5   2014-301     Auckland    Hard         28             A      20140106
# 6   2014-301     Auckland    Hard         28             A      20140106
# 7   2014-301     Auckland    Hard         28             A      20140106
# 8   2014-301     Auckland    Hard         28             A      20140106
# 9   2014-301     Auckland    Hard         28             A      20140106
#
#    match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 0          1     105385          NaN            Q    ...          3.0   2.0
# ...

# %%
for cell in df_2014['w_svpt']:
	if cell  == 0:
		print("zero in cell")
# Out:
# zero in cell

# %%
clean_df_2014=df_2014[(df_2014 != 0).all(1)]
clean_df_2014.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2014-301     Auckland    Hard         28             A      20140106
# 1   2014-301     Auckland    Hard         28             A      20140106
# 3   2014-301     Auckland    Hard         28             A      20140106
# 4   2014-301     Auckland    Hard         28             A      20140106
# 5   2014-301     Auckland    Hard         28             A      20140106
#
#    match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 0          1     105385          NaN            Q    ...          3.0   2.0
# 1          2     105053          NaN          NaN    ...          3.0   1.0
# 3          4     105449          NaN           LL    ...          2.0   8.0
# 4          5     104229          NaN          NaN    ...          3.0  11.0
# 5          6     105614          NaN            Q    ...          7.0   8.0
#
# ...

# %%
clean_df_2014['full_count'] = clean_df_2014.apply(lambda x: x.count(), axis=1)
clean_df_2014
# Out:
# /Users/forrestbadgley/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      tourney_id                 tourney_name surface  draw_size tourney_level  \
# 0      2014-301                     Auckland    Hard         28             A
# 1      2014-301                     Auckland    Hard         28             A
# 3      2014-301                     Auckland    Hard         28             A
# 4      2014-301                     Auckland    Hard         28             A
# 5      2014-301                     Auckland    Hard         28             A
# 7      2014-301                     Auckland    Hard         28             A
# ...

# %%
clean_df_2014= clean_df_2014[np.isfinite(clean_df_2014['w_svpt'])]
clean_df_2014
# Out:
#      tourney_id     tourney_name surface  draw_size tourney_level  \
# 0      2014-301         Auckland    Hard         28             A
# 1      2014-301         Auckland    Hard         28             A
# 3      2014-301         Auckland    Hard         28             A
# 4      2014-301         Auckland    Hard         28             A
# 5      2014-301         Auckland    Hard         28             A
# 7      2014-301         Auckland    Hard         28             A
# 8      2014-301         Auckland    Hard         28             A
# 10     2014-301         Auckland    Hard         28             A
# 12     2014-301         Auckland    Hard         28             A
# 13     2014-301         Auckland    Hard         28             A
# 14     2014-301         Auckland    Hard         28             A
# 15     2014-301         Auckland    Hard         28             A
# 17     2014-301         Auckland    Hard         28             A
# ...

# %%
tourney_date=[]
l_player_id=[]
w_player_id=[]
w_player_name=[]
l_player_name=[]
w_rank=[]
l_rank=[]
w_age=[]
l_age=[]
w_fst_srv_pct_lst=[]
l_fst_srv_pct_lst=[]
w_scd_srv_pct_lst=[]
l_scd_srv_pct_lst=[]
w_bp_saved_pct_lst=[]
l_bp_saved_pct_lst=[]

for i, row in clean_df_2014.iterrows():
    w_fst_srv_pct = row['w_1stWon']/row['w_svpt']#winner first serve percentage
    w_fst_srv_pct_lst.append(w_fst_srv_pct)
    l_fst_srv_pct = row['l_1stWon']/row['l_svpt']
    l_fst_srv_pct_lst.append(l_fst_srv_pct)
    w_player_id.append(row['winner_id'])
    l_player_id.append(row['loser_id'])
    w_age.append(row['winner_age'])
    l_age.append(row['loser_age'])
    w_player_name.append(row['winner_name'])
    l_player_name.append(row['loser_name'])
    w_scd_srv_pct= row['w_2ndWon']/row['w_svpt']#second serve % 
    w_scd_srv_pct_lst.append(w_scd_srv_pct)
    l_scd_srv_pct= row['l_2ndWon']/row['l_svpt']
    l_scd_srv_pct_lst.append(l_scd_srv_pct)
    w_rank.append(row['winner_rank'])
    l_rank.append(row['loser_rank'])
    w_bp_saved_pct = row['w_bpSaved']/row['w_bpFaced']#break point saved %
    w_bp_saved_pct_lst.append(w_bp_saved_pct)
    l_bp_saved_pct = row['l_bpSaved']/row['l_bpFaced']
    l_bp_saved_pct_lst.append(l_bp_saved_pct)
    tourney_date.append(row['tourney_date'])
print(len(w_fst_srv_pct_lst),len(l_fst_srv_pct_lst), len(w_player_id), len(l_player_id), len(w_age), len(l_age), len(l_rank), len(w_rank), len(w_scd_srv_pct_lst), len(l_scd_srv_pct_lst),len(w_bp_saved_pct_lst), len(w_player_name), len(l_player_name),len(l_bp_saved_pct_lst),len(tourney_date))
rows= zip(tourney_date,
l_player_id,
w_player_id,
w_player_name,
l_player_name,
w_rank,
l_rank,
w_age,
l_age,
w_fst_srv_pct_lst,
l_fst_srv_pct_lst,
w_scd_srv_pct_lst,
l_scd_srv_pct_lst,
w_bp_saved_pct_lst,
l_bp_saved_pct_lst
)
headers=['tourney_date',
'loser_player_id',
'winner_player_id',
'w_player_name',
'l_player_name',
'winner_rank',
'loser_rank',
'winner_age',
'loser_age',
'w_fst_srv_pct',
'l_fst_srv_pct',
'w_scd_srv_pct',
'l_scd_srv_pct',
'w_bp_saved_pct',
'l_bp_saved_pct']
# Out:
# 1834 1834 1834 1834 1834 1834 1834 1834 1834 1834 1834 1834 1834 1834 1834

# %%
csvfile = "/Users/forrestbadgley/Documents/DataScience/Homework/FinalProject/pre_processed/tennis_2014_processed.csv"

with open(csvfile, "w") as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    for row in rows:
        writer.writerow(row)

# %%
df = pd.read_csv('pre_processed/tennis_2014_processed.csv')
df.head(10)
# Out:
#    tourney_date  loser_player_id  winner_player_id           w_player_name  \
# 0      20140106           105643            105385            Donald Young
# 1      20140106           103656            105053        Santiago Giraldo
# 2      20140106           104571            105449           Steve Johnson
# 3      20140106           104997            104229             Yen Hsun Lu
# 4      20140106           104978            105614           Bradley Klahn
# 5      20140106           103835            104547        Horacio Zeballos
# 6      20140106           104907            105041             Lukas Lacko
# 7      20140106           104593            105138   Roberto Bautista Agut
# 8      20140106           105385            103970            David Ferrer
# 9      20140106           105053            104198  Guillermo Garcia Lopez
#
#           l_player_name  winner_rank  loser_rank  winner_age  loser_age  \
# ...
