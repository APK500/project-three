# %%
import pandas as pd
import numpy as np
from itertools import combinations, product
from ast import literal_eval

# %%
atp_2015 = pd.read_csv("atp_2015.csv")

# %%
frames = [atp_2015["winner_name"],atp_2015["loser_name"]]

# %%
results = pd.concat(frames)

# %%
players = results.unique()

# %%
atp_2015_win_lose = atp_2015[['winner_name','loser_name']]

# %%
atp_2015_win_lose = atp_2015_win_lose.dropna(axis=0,how="any")

# %%
atp_2015_opponents_win = atp_2015_win_lose.groupby("winner_name")["loser_name"].apply(list)
atp_2015_opponents_loss = atp_2015_win_lose.groupby("loser_name")["winner_name"].apply(list)
atp_2015_opponents_loss = pd.DataFrame(atp_2015_opponents_loss)
atp_2015_opponents_loss = atp_2015_opponents_loss.reset_index()
atp_2015_opponents_win = pd.DataFrame(atp_2015_opponents_win)
atp_2015_opponents_win = atp_2015_opponents_win.reset_index()
atp_2015_opponents_win = atp_2015_opponents_win.rename(index=str, columns={"winner_name": "name","loser_name":"wins"})
atp_2015_opponents_loss = atp_2015_opponents_loss.rename(index=str, columns={"loser_name": "name","winner_name":"losses"})

# %%
merge_table = pd.merge(atp_2015_opponents_loss, atp_2015_opponents_win, on="name", how="outer")
merge_table.to_csv("merge_table.csv")

# %%
##i manually changed the csv..dont judge :P

# %%
merge_table.head()
# Out:
#                        name  \
# 0          Adrian Mannarino
# 1  Adrian Menendez Maceiras
# 2             Adrien Bossel
# 3           Albert Montanes
# 4              Albert Ramos
#
#                                               losses  \
# 0  [Steve Darcis, Andreas Seppi, John Isner, Domi...
# 1  [Paolo Lorenzi, Tim Smyczek, Bernard Tomic, Al...
# 2                                     [Dustin Brown]
# 3  [David Ferrer, Thomaz Bellucci, Pablo Cuevas, ...
# 4  [Nick Kyrgios, Jo Wilfried Tsonga, Pablo Anduj...
#
#                                                 wins
# 0  [Michael Berrer, Mischa Zverev, Fabio Fognini,...
# 1                               [Alejandro Gonzalez]
# 2                                                NaN
# 3  [Ricardas Berankis, Facundo Arguello, Santiago...
# 4  [Sam Querrey, Roger Federer, Denis Istomin, Vi...

# %%
merge_table = pd.read_csv("merge_table.csv")

# %%
# merge_table["losses"] = literal_eval(merge_table["losses"].values)

##fun fact: the lists are strings and not lists! this changes it back (necessary for later stuff)

# %%
merge_table.loc[:,'losses'] = merge_table.loc[:,'losses'].apply(lambda x: literal_eval(x))

# %%
merge_table.loc[:,'wins'] = merge_table.loc[:,'wins'].apply(lambda x: literal_eval(x))

# %%
merge_table.head()
# Out:
#                        name  \
# 0          Adrian Mannarino
# 1  Adrian Menendez Maceiras
# 2             Adrien Bossel
# 3           Albert Montanes
# 4              Albert Ramos
#
#                                               losses  \
# 0  [Steve Darcis, Andreas Seppi, John Isner, Domi...
# 1  [Paolo Lorenzi, Tim Smyczek, Bernard Tomic, Al...
# 2                                     [Dustin Brown]
# 3  [David Ferrer, Thomaz Bellucci, Pablo Cuevas, ...
# 4  [Nick Kyrgios, Jo Wilfried Tsonga, Pablo Anduj...
#
#                                                 wins
# 0  [Michael Berrer, Mischa Zverev, Fabio Fognini,...
# 1                               [Alejandro Gonzalez]
# 2                                              [Bye]
# 3  [Ricardas Berankis, Facundo Arguello, Santiago...
# 4  [Sam Querrey, Roger Federer, Denis Istomin, Vi...

# %%
prod = list(product(atp_2015_win_lose['loser_name'].unique(), atp_2015_win_lose['loser_name'].unique()))

# %%
len(prod)
# Out:
# 79524

# %%
all_possible_matches = pd.DataFrame(prod)

# %%
all_possible_matches.head()
# Out:
#                 0                   1
# 0  Radek Stepanek      Radek Stepanek
# 1  Radek Stepanek  Yoshihito Nishioka
# 2  Radek Stepanek       Matthew Ebden
# 3  Radek Stepanek     Feliciano Lopez
# 4  Radek Stepanek     Mikhail Youzhny

# %%
all_possible_matches = all_possible_matches.rename(index=str, columns={0: "player_1",1:"player_2"})

# %%
all_possible_matches = all_possible_matches.drop(all_possible_matches[all_possible_matches.player_1 == all_possible_matches.player_2].index)

# %%
all_possible_matches
# Out:
#                player_1                  player_2
# 1        Radek Stepanek        Yoshihito Nishioka
# 2        Radek Stepanek             Matthew Ebden
# 3        Radek Stepanek           Feliciano Lopez
# 4        Radek Stepanek           Mikhail Youzhny
# 5        Radek Stepanek         Yasutaka Uchiyama
# 6        Radek Stepanek              Samuel Groth
# 7        Radek Stepanek            Kevin Anderson
# 8        Radek Stepanek           Grigor Dimitrov
# 9        Radek Stepanek         Fernando Verdasco
# 10       Radek Stepanek              Albert Ramos
# 11       Radek Stepanek           Richard Gasquet
# 12       Radek Stepanek              Donald Young
# 13       Radek Stepanek             Bernard Tomic
# 14       Radek Stepanek       Alexandr Dolgopolov
# 15       Radek Stepanek               Borna Coric
# 16       Radek Stepanek               Tatsuma Ito
# 17       Radek Stepanek                Joao Sousa
# 18       Radek Stepanek               Jiri Vesely
# 19       Radek Stepanek             Jeremy Chardy
# 20       Radek Stepanek          Marcos Baghdatis
# 21       Radek Stepanek     Roberto Bautista Agut
# 22       Radek Stepanek             Steve Johnson
# 23       Radek Stepanek               Sam Querrey
# 24       Radek Stepanek           Austin Krajicek
# 25       Radek Stepanek              Gilles Simon
# 26       Radek Stepanek              Nick Kyrgios
# 27       Radek Stepanek               Marin Cilic
# 28       Radek Stepanek             Gilles Muller
# 29       Radek Stepanek             Kei Nishikori
# 30       Radek Stepanek              Benoit Paire
# ...                 ...                       ...
# 79493  Germain Gigounon               Taro Daniel
# 79494  Germain Gigounon             Daniel Brands
# 79495  Germain Gigounon              Antonio Veic
# 79496  Germain Gigounon        Mikhail Ledovskikh
# 79497  Germain Gigounon            Farrukh Dustov
# 79498  Germain Gigounon               Darian King
# 79499  Germain Gigounon       Christopher Eubanks
# 79500  Germain Gigounon    Inigo Cervantes Huegun
# 79501  Germain Gigounon             Federico Gaio
# 79502  Germain Gigounon             Matteo Donati
# 79503  Germain Gigounon              Andreas Beck
# 79504  Germain Gigounon         Benjamin Balleret
# 79505  Germain Gigounon           Jabor Al Mutawa
# 79506  Germain Gigounon            Mohamed Safwat
# 79507  Germain Gigounon          Yassine Idmbarek
# 79508  Germain Gigounon           Arthur De Greef
# 79509  Germain Gigounon             Lamine Ouahab
# 79510  Germain Gigounon            Aslan Karatsev
# 79511  Germain Gigounon        Jose Rubin Statham
# 79512  Germain Gigounon                David Guez
# 79513  Germain Gigounon                Mate Pavic
# 79514  Germain Gigounon        Constant Lestienne
# 79515  Germain Gigounon            Martin Fischer
# 79516  Germain Gigounon  Frederico Ferreira Silva
# 79517  Germain Gigounon              Gastao Elias
# 79518  Germain Gigounon      David Vega Hernandez
# 79519  Germain Gigounon               Rui Machado
# 79520  Germain Gigounon            Yaraslau Shyla
# 79521  Germain Gigounon       Alexandre Sidorenko
# 79522  Germain Gigounon              Eric Quigley
#
# [79242 rows x 2 columns]

# %%
# all_possible_matches["player_1_wins"] = merge_table.loc([merge_table['name'] == all_possible_matches["player_1"], ['wins']])

# %%
merge_table_test = merge_table.rename(index=str, columns = {"name":"player_1"})

# %%
merge_table_test.head()
# Out:
#                    player_1  \
# 0          Adrian Mannarino
# 1  Adrian Menendez Maceiras
# 2             Adrien Bossel
# 3           Albert Montanes
# 4              Albert Ramos
#
#                                               losses  \
# 0  [Steve Darcis, Andreas Seppi, John Isner, Domi...
# 1  [Paolo Lorenzi, Tim Smyczek, Bernard Tomic, Al...
# 2                                     [Dustin Brown]
# 3  [David Ferrer, Thomaz Bellucci, Pablo Cuevas, ...
# 4  [Nick Kyrgios, Jo Wilfried Tsonga, Pablo Anduj...
#
#                                                 wins
# 0  [Michael Berrer, Mischa Zverev, Fabio Fognini,...
# 1                               [Alejandro Gonzalez]
# 2                                              [Bye]
# 3  [Ricardas Berankis, Facundo Arguello, Santiago...
# 4  [Sam Querrey, Roger Federer, Denis Istomin, Vi...

# %%
all_possible_matches.head()
# Out:
#          player_1            player_2
# 1  Radek Stepanek  Yoshihito Nishioka
# 2  Radek Stepanek       Matthew Ebden
# 3  Radek Stepanek     Feliciano Lopez
# 4  Radek Stepanek     Mikhail Youzhny
# 5  Radek Stepanek   Yasutaka Uchiyama

# %%
matching_merge = pd.merge(all_possible_matches,merge_table_test, on = "player_1", how = "outer")

# %%
matching_merge.head()
# Out:
#          player_1            player_2  \
# 0  Radek Stepanek  Yoshihito Nishioka
# 1  Radek Stepanek       Matthew Ebden
# 2  Radek Stepanek     Feliciano Lopez
# 3  Radek Stepanek     Mikhail Youzhny
# 4  Radek Stepanek   Yasutaka Uchiyama
#
#                                               losses  \
# 0  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 1  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 2  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 3  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 4  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
#
#                                                 wins
# 0  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 1  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 2  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 3  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 4  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...

# %%
matching_merge = matching_merge.rename(index = str, columns = {"losses": "player_1_losses","wins": "player_1_wins"})

# %%
matching_merge.head()
# Out:
#          player_1            player_2  \
# 0  Radek Stepanek  Yoshihito Nishioka
# 1  Radek Stepanek       Matthew Ebden
# 2  Radek Stepanek     Feliciano Lopez
# 3  Radek Stepanek     Mikhail Youzhny
# 4  Radek Stepanek   Yasutaka Uchiyama
#
#                                      player_1_losses  \
# 0  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 1  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 2  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 3  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 4  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
#
#                                        player_1_wins
# 0  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 1  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 2  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 3  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 4  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...

# %%
merge_table_test = merge_table.rename(index=str, columns = {"name":"player_2"})

# %%
merge_table_test.head()
# Out:
#                    player_2  \
# 0          Adrian Mannarino
# 1  Adrian Menendez Maceiras
# 2             Adrien Bossel
# 3           Albert Montanes
# 4              Albert Ramos
#
#                                               losses  \
# 0  [Steve Darcis, Andreas Seppi, John Isner, Domi...
# 1  [Paolo Lorenzi, Tim Smyczek, Bernard Tomic, Al...
# 2                                     [Dustin Brown]
# 3  [David Ferrer, Thomaz Bellucci, Pablo Cuevas, ...
# 4  [Nick Kyrgios, Jo Wilfried Tsonga, Pablo Anduj...
#
#                                                 wins
# 0  [Michael Berrer, Mischa Zverev, Fabio Fognini,...
# 1                               [Alejandro Gonzalez]
# 2                                              [Bye]
# 3  [Ricardas Berankis, Facundo Arguello, Santiago...
# 4  [Sam Querrey, Roger Federer, Denis Istomin, Vi...

# %%
matching_merge_1 = pd.merge(all_possible_matches,merge_table_test, on = "player_2", how = "outer")

# %%
matching_merge_1 = matching_merge_1.rename(index = str, columns = {"losses": "player_2_losses","wins": "player_2_wins"})

# %%
matching_merge_1.head()
# Out:
#             player_1            player_2  \
# 0     Radek Stepanek  Yoshihito Nishioka
# 1      Matthew Ebden  Yoshihito Nishioka
# 2    Feliciano Lopez  Yoshihito Nishioka
# 3    Mikhail Youzhny  Yoshihito Nishioka
# 4  Yasutaka Uchiyama  Yoshihito Nishioka
#
#                                      player_2_losses  \
# 0  [Tatsuma Ito, Thomaz Bellucci, Alexander Zvere...
# 1  [Tatsuma Ito, Thomaz Bellucci, Alexander Zvere...
# 2  [Tatsuma Ito, Thomaz Bellucci, Alexander Zvere...
# 3  [Tatsuma Ito, Thomaz Bellucci, Alexander Zvere...
# 4  [Tatsuma Ito, Thomaz Bellucci, Alexander Zvere...
#
#                                        player_2_wins
# 0  [Paul Henri Mathieu, Igor Sijsling, Marinko Ma...
# 1  [Paul Henri Mathieu, Igor Sijsling, Marinko Ma...
# 2  [Paul Henri Mathieu, Igor Sijsling, Marinko Ma...
# 3  [Paul Henri Mathieu, Igor Sijsling, Marinko Ma...
# 4  [Paul Henri Mathieu, Igor Sijsling, Marinko Ma...

# %%
attempt_merge = pd.merge(matching_merge, matching_merge_1,  how='left', left_on=['player_1','player_2'], right_on = ['player_1','player_2'])

# %%
##i dont know why there are NAs

attempt_merge1 = attempt_merge.dropna(axis=0,how="any")

# %%
attempt_merge1.head()
# Out:
#          player_1            player_2  \
# 0  Radek Stepanek  Yoshihito Nishioka
# 1  Radek Stepanek       Matthew Ebden
# 2  Radek Stepanek     Feliciano Lopez
# 3  Radek Stepanek     Mikhail Youzhny
# 4  Radek Stepanek   Yasutaka Uchiyama
#
#                                      player_1_losses  \
# 0  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 1  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 2  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 3  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 4  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
#
#                                        player_1_wins  \
# 0  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 1  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 2  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 3  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 4  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
#
#                                      player_2_losses  \
# 0  [Tatsuma Ito, Thomaz Bellucci, Alexander Zvere...
# 1  [Austin Krajicek, John Isner, Tatsuma Ito, Gri...
# 2  [Joao Sousa, Roger Federer, Novak Djokovic, Vi...
# 3  [Gilles Simon, Bastian Trinker, Thomaz Bellucc...
# 4                      [Jiri Vesely, Vasek Pospisil]
#
#                                        player_2_wins
# 0  [Paul Henri Mathieu, Igor Sijsling, Marinko Ma...
# 1                                        [Blaz Rola]
# 2  [Milos Raonic, Andreas Seppi, Rafael Nadal, An...
# 3  [Viktor Troicki, Gilles Simon, Andrey Golubev,...
# 4                                              [Bye]

# %%
attempt_merge1['player_1_losses_in_player_2_wins'] = [list(set(a).intersection(set(b))) for a, b in zip(attempt_merge1.player_1_losses,attempt_merge1.player_2_wins)]

# %%
attempt_merge1['player_2_losses_in_player_1_wins'] = [list(set(a).intersection(set(b))) for a, b in zip(attempt_merge1.player_2_losses,attempt_merge1.player_1_wins)]

# %%
attempt_merge1['player_1_wins_in_player_2_wins'] = [list(set(a).intersection(set(b))) for a, b in zip(attempt_merge1.player_1_wins,attempt_merge1.player_2_wins)]
attempt_merge1['player_1_losses_in_player_2_losses'] = [list(set(a).intersection(set(b))) for a, b in zip(attempt_merge1.player_1_losses,attempt_merge1.player_2_losses)]

# %%
[list(len(a+b)) for a, b in zip(attempt_merge1.player_1_losses_in_player_2_wins,attempt_merge1.player_2_losses_in_player_1_wins)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-043184973d5f> in <module>()
# ----> 1 [list(len(a+b)) for a, b in zip(attempt_merge1.player_1_losses_in_player_2_wins,attempt_merge1.player_2_losses_in_player_1_wins)]
#
# <ipython-input-60-043184973d5f> in <listcomp>(.0)
# ----> 1 [list(len(a+b)) for a, b in zip(attempt_merge1.player_1_losses_in_player_2_wins,attempt_merge1.player_2_losses_in_player_1_wins)]
#
# TypeError: 'int' object is not iterable

# %%
attempt_merge1.head(20)
# Out:
#           player_1             player_2  \
# 0   Radek Stepanek   Yoshihito Nishioka
# 1   Radek Stepanek        Matthew Ebden
# 2   Radek Stepanek      Feliciano Lopez
# 3   Radek Stepanek      Mikhail Youzhny
# 4   Radek Stepanek    Yasutaka Uchiyama
# 5   Radek Stepanek         Samuel Groth
# 6   Radek Stepanek       Kevin Anderson
# 7   Radek Stepanek      Grigor Dimitrov
# 8   Radek Stepanek    Fernando Verdasco
# 9   Radek Stepanek         Albert Ramos
# 10  Radek Stepanek      Richard Gasquet
# 11  Radek Stepanek         Donald Young
# 12  Radek Stepanek        Bernard Tomic
# 13  Radek Stepanek  Alexandr Dolgopolov
# 14  Radek Stepanek          Borna Coric
# 15  Radek Stepanek          Tatsuma Ito
# 16  Radek Stepanek           Joao Sousa
# 17  Radek Stepanek          Jiri Vesely
# 18  Radek Stepanek        Jeremy Chardy
# 19  Radek Stepanek     Marcos Baghdatis
#
#                                       player_1_losses  \
# 0   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 1   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 2   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 3   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 4   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 5   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 6   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 7   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 8   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 9   [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 10  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 11  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 12  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 13  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 14  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 15  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 16  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 17  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 18  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
# 19  [Stanislas Wawrinka, Aljaz Bedene, David Ferre...
#
#                                         player_1_wins  \
# 0   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 1   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 2   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 3   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 4   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 5   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 6   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 7   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 8   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 9   [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 10  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 11  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 12  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 13  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 14  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 15  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 16  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 17  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 18  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
# 19  [Yuichi Sugita, Edouard Roger Vasselin, Samuel...
#
#                                       player_2_losses  \
# 0   [Tatsuma Ito, Thomaz Bellucci, Alexander Zvere...
# 1   [Austin Krajicek, John Isner, Tatsuma Ito, Gri...
# 2   [Joao Sousa, Roger Federer, Novak Djokovic, Vi...
# 3   [Gilles Simon, Bastian Trinker, Thomaz Bellucc...
# 4                       [Jiri Vesely, Vasek Pospisil]
# 5   [Jeremy Chardy, Roger Federer, Benjamin Becker...
# 6   [Gilles Muller, Roger Federer, Jo Wilfried Tso...
# 7   [Benoit Paire, Tomas Berdych, Andy Murray, Dav...
# 8   [Marcos Baghdatis, Jack Sock, David Goffin, Be...
# 9   [Nick Kyrgios, Jo Wilfried Tsonga, Pablo Anduj...
# 10  [Roberto Bautista Agut, Jack Sock, Andy Murray...
# 11  [Marin Cilic, Victor Estrella, Marcos Baghdati...
# 12  [Steve Johnson, Marcos Baghdatis, Alexandr Dol...
# 13  [Sam Querrey, Novak Djokovic, Borna Coric, Dav...
# 14  [Kei Nishikori, Roberto Bautista Agut, Stanisl...
# 15  [Stanislas Wawrinka, Nick Kyrgios, Guillermo G...
# 16  [Austin Krajicek, Dominic Thiem, Marin Cilic, ...
# 17  [Gilles Simon, Fabio Fognini, Thomaz Bellucci,...
# 18  [Gilles Muller, Richard Gasquet, Rafael Nadal,...
# 19  [Benoit Paire, Tomas Berdych, David Goffin, Va...
#
#                                         player_2_wins  \
# 0   [Paul Henri Mathieu, Igor Sijsling, Marinko Ma...
# 1                                         [Blaz Rola]
# 2   [Milos Raonic, Andreas Seppi, Rafael Nadal, An...
# 3   [Viktor Troicki, Gilles Simon, Andrey Golubev,...
# 4                                               [Bye]
# 5   [Jack Sock, James Duckworth, Yen Hsun Lu, Lley...
# 6   [Leonardo Mayer, Jack Sock, Tommy Haas, Fabio ...
# 7   [Filip Krajinovic, Nicolas Almagro, Lukas Roso...
# 8   [Denis Kudla, Jo Wilfried Tsonga, Martin Kliza...
# 9   [Sam Querrey, Roger Federer, Denis Istomin, Vi...
# 10  [Steve Darcis, Jeremy Chardy, Nick Kyrgios, Th...
# 11  [Denis Kudla, Tomas Berdych, Pablo Carreno Bus...
# 12  [Sergiy Stakhovsky, Fernando Verdasco, David F...
# 13  [Bernard Tomic, Jerzy Janowicz, Tomas Berdych,...
# 14  [Marcel Granollers, Aljaz Bedene, Alexander Zv...
# 15  [Yoshihito Nishioka, Jarkko Nieminen, Ramkumar...
# 16  [Feliciano Lopez, Toni Androic, Andreas Seppi,...
# 17  [Yasutaka Uchiyama, Paolo Lorenzi, N Vijay Sun...
# 18  [Samuel Groth, Thanasi Kokkinakis, Federico De...
# 19  [Fernando Verdasco, Sam Querrey, Bernard Tomic...
#
#                      player_1_losses_in_player_2_wins  \
# 0                                                  []
# 1                                                  []
# 2                       [Fabio Fognini, Marsel Ilhan]
# 3                                                  []
# 4                                                  []
# 5                                         [Jack Sock]
# 6   [Stanislas Wawrinka, Jack Sock, Fabio Fognini,...
# 7                 [Stanislas Wawrinka, Fabio Fognini]
# 8                             [Roberto Bautista Agut]
# 9                                                  []
# 10  [Ivo Karlovic, Stanislas Wawrinka, Roberto Bau...
# 11                      [Aljaz Bedene, Tomas Berdych]
# 12                      [Fabio Fognini, David Ferrer]
# 13                      [Ivo Karlovic, Tomas Berdych]
# 14                                     [Aljaz Bedene]
# 15                                                 []
# 16             [Fabio Fognini, Roberto Bautista Agut]
# 17                       [Ivo Karlovic, Aljaz Bedene]
# 18           [Ivo Karlovic, David Ferrer, John Isner]
# 19                       [Ivo Karlovic, David Ferrer]
#
#    player_2_losses_in_player_1_wins          player_1_wins_in_player_2_wins  \
# 0                                []                                      []
# 1                                []                                      []
# 2                    [Samuel Groth]  [Samuel Groth, Edouard Roger Vasselin]
# 3                                []                                      []
# 4                                []                                      []
# 5                                []                                      []
# 6                                []                          [Samuel Groth]
# 7                                []                            [Ivan Dodig]
# 8                                []                                      []
# 9                                []                                      []
# 10                               []                                      []
# 11                               []                            [Ivan Dodig]
# 12                               []                          [Samuel Groth]
# 13                   [Samuel Groth]                          [Samuel Groth]
# 14                               []                          [Samuel Groth]
# 15                               []                                      []
# 16                     [Ivan Dodig]  [Samuel Groth, Edouard Roger Vasselin]
# 17                               []                                      []
# 18                               []                          [Samuel Groth]
# 19                               []                          [Samuel Groth]
#
#                    player_1_losses_in_player_2_losses
# 0                                     [Tomas Berdych]
# 1                                        [John Isner]
# 2   [Aljaz Bedene, David Ferrer, Marsel Ilhan, Joh...
# 3                          [Aljaz Bedene, John Isner]
# 4                                                  []
# 5                                                  []
# 6         [Stanislas Wawrinka, Jack Sock, John Isner]
# 7   [David Ferrer, Tomas Berdych, Jack Sock, Fabio...
# 8       [Stanislas Wawrinka, Jack Sock, David Ferrer]
# 9   [Stanislas Wawrinka, Fabio Fognini, David Ferrer]
# 10  [Jack Sock, David Ferrer, Roberto Bautista Agu...
# 11      [Ivo Karlovic, Stanislas Wawrinka, Jack Sock]
# 12  [Stanislas Wawrinka, David Ferrer, Tomas Berdych]
# 13                       [Ivo Karlovic, David Ferrer]
# 14  [Stanislas Wawrinka, Roberto Bautista Agut, To...
# 15  [Ivo Karlovic, Stanislas Wawrinka, Fabio Fogni...
# 16    [Stanislas Wawrinka, Fabio Fognini, John Isner]
# 17         [Fabio Fognini, John Isner, Tomas Berdych]
# 18  [Ivo Karlovic, Aljaz Bedene, Fabio Fognini, To...
# 19                        [John Isner, Tomas Berdych]

# %%
list(zip(attempt_merge1.player_1_losses,attempt_merge1.player_2_losses))[0]
# Out:
# (['Stanislas Wawrinka',
#   'Aljaz Bedene',
#   'David Ferrer',
#   'Ivo Karlovic',
#   'Marsel Ilhan',
#   'Fabio Fognini',
#   'Jack Sock',
#   'Roberto Bautista Agut',
#   'John Isner',
#   'Tomas Berdych'],
#  ['Tatsuma Ito',
#   'Thomaz Bellucci',
#   'Alexander Zverev',
#   'Bernard Tomic',
#   'Tomas Berdych'])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-c873af58fcaf> in <module>()
# ----> 1 concat(attempt_merge1.player_1_losses,attempt_merge1.player_2_wins)
#
# NameError: name 'concat' is not defined

# %%
attempt_merge.replace(np.NaN, ["none"])

# %%
attempt_merge

# %%
h = list(zip(attempt_merge.player_1_losses,attempt_merge.player_2_wins))

# %%
attempt_merge.head(20)

# %%
attempt_merge["player_1_wins"][0]

# %%
attempt_merge["player_2_losses"][0]

# %%
s = pd.Series(attempt_merge["player_1_wins"], name='player_1_wins')

# %%
s.isin(attempt_merge["player_2_losses"][0])

# %%
s[0]
